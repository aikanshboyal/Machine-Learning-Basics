# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = sns.load_dataset("iris")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df["sepal_length"]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
names = ["anuj", "ravi", "mohit"]

# %%
ages = [26, 34, 21]

# %%
d = {
    "names" : names,
    "age" : ages
}

# %%
d
# Out:
# {'names': ['anuj', 'ravi', 'mohit'], 'age': [26, 34, 21]}

# %%
pd.DataFrame(d)
# Out:
#    names  age
# 0   anuj   26
# 1   ravi   34
# 2  mohit   21

# %%
import numpy as np

# %%
data = np.random.randint(10, 20, (10,5))

# %%
data
# Out:
# array([[16, 17, 10, 12, 15],
#        [11, 12, 12, 11, 15],
#        [19, 12, 13, 18, 15],
#        [16, 19, 16, 15, 12],
#        [10, 17, 16, 11, 15],
#        [16, 16, 11, 10, 13],
#        [14, 10, 10, 12, 10],
#        [19, 13, 12, 19, 13],
#        [10, 19, 12, 14, 12],
#        [16, 19, 16, 17, 14]])

# %%
marks = pd.DataFrame(data, columns=["Physics", "Maths", "Chemistry", "Biology", "IT"])

# %%
marks
# Out:
#    Physics  Maths  Chemistry  Biology  IT
# 0       16     17         10       12  15
# 1       11     12         12       11  15
# 2       19     12         13       18  15
# 3       16     19         16       15  12
# 4       10     17         16       11  15
# 5       16     16         11       10  13
# 6       14     10         10       12  10
# 7       19     13         12       19  13
# 8       10     19         12       14  12
# 9       16     19         16       17  14

# %%
marks["Social Science"] = 0

# %%
marks
# Out:
#    Physics  Maths  Chemistry  Biology  IT  Social Science
# 0       16     17         10       12  15               0
# 1       11     12         12       11  15               0
# 2       19     12         13       18  15               0
# 3       16     19         16       15  12               0
# 4       10     17         16       11  15               0
# 5       16     16         11       10  13               0
# 6       14     10         10       12  10               0
# 7       19     13         12       19  13               0
# 8       10     19         12       14  12               0
# 9       16     19         16       17  14               0

# %%
 df.values
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 'setosa'],
#        [4.9, 3.0, 1.4, 0.2, 'setosa'],
#        [4.7, 3.2, 1.3, 0.2, 'setosa'],
#        [4.6, 3.1, 1.5, 0.2, 'setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'setosa'],
#        [5.4, 3.9, 1.7, 0.4, 'setosa'],
#        [4.6, 3.4, 1.4, 0.3, 'setosa'],
#        [5.0, 3.4, 1.5, 0.2, 'setosa'],
#        [4.4, 2.9, 1.4, 0.2, 'setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'setosa'],
#        [5.4, 3.7, 1.5, 0.2, 'setosa'],
#        [4.8, 3.4, 1.6, 0.2, 'setosa'],
#        [4.8, 3.0, 1.4, 0.1, 'setosa'],
#        [4.3, 3.0, 1.1, 0.1, 'setosa'],
#        [5.8, 4.0, 1.2, 0.2, 'setosa'],
#        [5.7, 4.4, 1.5, 0.4, 'setosa'],
#        [5.4, 3.9, 1.3, 0.4, 'setosa'],
#        [5.1, 3.5, 1.4, 0.3, 'setosa'],
#        [5.7, 3.8, 1.7, 0.3, 'setosa'],
#        [5.1, 3.8, 1.5, 0.3, 'setosa'],
#        [5.4, 3.4, 1.7, 0.2, 'setosa'],
#        [5.1, 3.7, 1.5, 0.4, 'setosa'],
#        [4.6, 3.6, 1.0, 0.2, 'setosa'],
#        [5.1, 3.3, 1.7, 0.5, 'setosa'],
# ...

# %%
df.describe() #some mathematical resultant for the data
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
marks.sort_values(["Maths"])
# Out:
#    Physics  Maths  Chemistry  Biology  IT  Social Science
# 6       14     10         10       12  10               0
# 1       11     12         12       11  15               0
# 2       19     12         13       18  15               0
# 7       19     13         12       19  13               0
# 5       16     16         11       10  13               0
# 0       16     17         10       12  15               0
# 4       10     17         16       11  15               0
# 3       16     19         16       15  12               0
# 8       10     19         12       14  12               0
# 9       16     19         16       17  14               0

# %%
marks.iloc[:5] # 5 items
# Out:
#    Physics  Maths  Chemistry  Biology  IT  Social Science
# 0       16     17         10       12  15               0
# 1       11     12         12       11  15               0
# 2       19     12         13       18  15               0
# 3       16     19         16       15  12               0
# 4       10     17         16       11  15               0

# %%
marks.iloc[:5, 1:3] # 5 items and 1 to 2 columns
# Out:
#    Maths  Chemistry
# 0     17         10
# 1     12         12
# 2     12         13
# 3     19         16
# 4     17         16

# %%
marks.iloc[ : : 2] #select every column with a jump of 2
# Out:
#    Physics  Maths  Chemistry  Biology  IT  Social Science
# 0       16     17         10       12  15               0
# 2       19     12         13       18  15               0
# 4       10     17         16       11  15               0
# 6       14     10         10       12  10               0
# 8       10     19         12       14  12               0
